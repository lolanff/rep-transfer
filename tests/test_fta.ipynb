# %%
import numpy as np
from utils.functions import fta
import matplotlib.pyplot as plt

# %%
eta = 0.25
k = 4

x_values = np.arange(100)/100
v = fta(x_values, eta=eta, tiles=k, lower_bound=0, upper_bound=1)

fig, axs = plt.subplots(4, 1, figsize=(5, 4))
for i in range(4):
    axs[i].plot(x_values, v[:, i], color='r')
    
plt.tight_layout()
# Out:
# WARNING:2025-01-28 16:10:51,680:jax._src.xla_bridge:969: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
print(fta(0, eta=eta, tiles=k, lower_bound=0, upper_bound=1))
# Out:
# [[1. 0. 0. 0.]]
